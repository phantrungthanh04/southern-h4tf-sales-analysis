# %% [markdown]
# # B1: Nhập Liệu

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_original = pd.read_excel('Customer Only.xlsx')
sales_original = pd.read_excel(r'Sales Only.xlsx')

# %% [markdown]
# # B2: EDA Bảng Customer

# %%
df_original.head()
# Out:
#   Customer Last Name Customer First Name  Customer ID Product Category  \
# 0             Hughes               Lewis         1234         Clothing
# 1              Gomez                 Ali         1235   Home & Kitchen
# 2               Beck                Mila         1236    Personal Care
# 3             Juarez             Ryleigh         1237    Personal Care
# 4            Preston            Leonidas         1238      Electronics
#
#   Order Date  Quantity Ordered Order Status State                 Address  \
# 0 2022-12-24                12    Delivered    LA   49458 Glenwood Avenue
# 1 2022-12-06                 2   In Transit    LA        11591 River Road
# 2 2022-12-01                 7    Delivered    GA    48087 Jackson Street
# 3 2022-12-25                 9    Delivered    NC  46798 Hillcrest Avenue
# 4 2022-12-29                 9      Shipped    GA   65693 Mulberry Street
#
#                City  Postal Code  Sale Price         Phone
# ...

# %%
# Kiểu dữ liệu
df_original.dtypes
# Out:
# Customer Last Name             object
# Customer First Name            object
# Customer ID                     int64
# Product Category               object
# Order Date             datetime64[ns]
# Quantity Ordered                int64
# Order Status                   object
# State                          object
# Address                        object
# City                           object
# Postal Code                     int64
# Sale Price                      int64
# Phone                          object
# dtype: object

# %%
# Check null
df_original.isnull().sum()
# Out:
# Customer Last Name     0
# Customer First Name    0
# Customer ID            0
# Product Category       0
# Order Date             0
# Quantity Ordered       0
# Order Status           0
# State                  0
# Address                0
# City                   0
# Postal Code            0
# Sale Price             0
# Phone                  0
# dtype: int64

# %%
# Check số giá trị unique
for i in range(len(df_original.columns)):
    print(df_original.columns[i] + ":", df_original.iloc[:,i].nunique())
# Out:
# Customer Last Name: 629
# Customer First Name: 607
# Customer ID: 998
# Product Category: 7
# Order Date: 31
# Quantity Ordered: 20
# Order Status: 4
# State: 6
# Address: 998
# City: 26
# Postal Code: 27
# Sale Price: 767
# Phone: 1000

# %%
# EDA các trường dữ liệu định lượng
df_original.describe()
# Out:
#        Customer ID                  Order Date  Quantity Ordered  \
# count   1000.00000                        1000       1000.000000
# mean    1731.99600  2022-12-15 22:50:52.800000         10.567000
# min     1234.00000         2022-12-01 00:00:00          1.000000
# 25%     1482.75000         2022-12-08 00:00:00          6.000000
# 50%     1731.50000         2022-12-16 00:00:00         11.000000
# 75%     1981.25000         2022-12-24 00:00:00         15.000000
# max     2231.00000         2022-12-31 00:00:00         20.000000
# std      288.21378                         NaN          5.768777
#
#         Postal Code   Sale Price
# count   1000.000000  1000.000000
# mean   38974.463000   890.427000
# min    27514.000000    11.000000
# 25%    29601.000000   431.750000
# 50%    33160.000000   897.000000
# 75%    36602.000000  1311.250000
# max    71101.000000  1904.000000
# std    15074.135668   514.266924

# %%
# EDA các biến định tính có số giá trị unique thấp
df_original.groupby('Product Category')['Product Category'].count()
# Out:
# Product Category
# Books                135
# Clothing             152
# Electronics          158
# Home & Kitchen       140
# Personal Care        150
# Pets                 135
# Sports & Outdoors    130
# Name: Product Category, dtype: int64

# %%
df_original.groupby('Order Status')['Order Status'].count()
# Out:
# Order Status
# Cancelled     103
# Delivered     400
# In Transit    110
# Shipped       387
# Name: Order Status, dtype: int64

# %%
df_original.groupby('State')['State'].count()
# Out:
# State
# AL    178
# FL    160
# GA    156
# LA    179
# NC    162
# SC    165
# Name: State, dtype: int64

# %% [markdown]
# Xử lý tình trạng cột primary key bị lặp dữ liệu

# %%
df_original[df_original.duplicated(subset = 'Customer ID', keep = False)]
# Out:
#     Customer Last Name Customer First Name  Customer ID   Product Category  \
# 139           Shepherd              Charli         1373           Clothing
# 354               Vega               Blake         1588              Books
# 381           Shepherd              Charli         1373  Sports & Outdoors
# 858               Vega               Blake         1588      Personal Care
#
#     Order Date  Quantity Ordered Order Status State                  Address  \
# 139 2022-12-05                20   In Transit    SC        81712 Main Street
# 354 2022-12-02                 5    Delivered    GA  63913 Valley View Drive
# 381 2022-12-03                17      Shipped    SC        81712 Main Street
# 858 2022-12-03                17      Shipped    GA  63913 Valley View Drive
#
#                  City  Postal Code  Sale Price         Phone
# 139        Greenville        29601         591  803-980-5972
# 354          Columbus        31901         329  762-827-9216
# ...

# %% [markdown]
# # B3: EDA Bảng Sales

# %%
sales_original.head()
# Out:
#    Order ID Customer Last Name Customer First Name  Customer ID  \
# 0      1489          Carpenter               Bodie         1721
# 1      1357              Costa             Brynlee         1590
# 2      1904              Frank              Collin         2135
# 3      1429              Nuñez                Kyle         1661
# 4      1099               Cruz              Alexis         1332
#
#     Product Category Order Date  Quantity Ordered Order Status State  \
# 0        Electronics 2022-10-01                 9    Delivered    NC
# 1        Electronics 2022-10-01                15    Delivered    AL
# 2           Clothing 2022-10-01                 4    Delivered    LA
# 3        Electronics 2022-10-01                18    Delivered    AL
# 4  Sports & Outdoors 2022-10-01                16    Delivered    NC
#
#    Manufacturer Price  Sale Price  Total Profit (GMROI) Sales Agent  \
# 0                 655         801                   146   Priscilla
# ...

# %%
# Check duplicates
sales_original.duplicated().sum()
# Out:
# 0

# %%
sales_original.isnull().sum()
# Out:
# Order ID                   0
# Customer Last Name         0
# Customer First Name        0
# Customer ID                0
# Product Category           0
# Order Date                 0
# Quantity Ordered           0
# Order Status               0
# State                      0
# Manufacturer Price         0
# Sale Price                 0
# Total Profit (GMROI)       0
# Sales Agent                0
# Return Reason           2691
# dtype: int64

# %%
# Check số giá trị unique
for i in range(len(sales_original.columns)):
    print(sales_original.columns[i] + ":", sales_original.iloc[:,i].nunique())
# Out:
# Order ID: 3000
# Customer Last Name: 629
# Customer First Name: 607
# Customer ID: 998
# Product Category: 7
# Order Date: 92
# Quantity Ordered: 20
# Order Status: 4
# State: 6
# Manufacturer Price: 299
# Sale Price: 1480
# Total Profit (GMROI): 412
# Sales Agent: 5
# Return Reason: 5

# %%
sales_original.describe()
# Out:
#           Order ID  Customer ID                  Order Date  Quantity Ordered  \
# count  3000.000000  3000.000000                        3000       3000.000000
# mean   2500.500000  1731.996000  2022-11-15 10:03:50.400000         10.503333
# min    1001.000000  1234.000000         2022-10-01 00:00:00          1.000000
# 25%    1750.750000  1482.750000         2022-10-23 00:00:00          6.000000
# 50%    2500.500000  1731.500000         2022-11-15 00:00:00         11.000000
# 75%    3250.250000  1981.250000         2022-12-08 00:00:00         15.000000
# max    4000.000000  2231.000000         2022-12-31 00:00:00         20.000000
# std     866.169729   288.117661                         NaN          5.785656
#
#        Manufacturer Price   Sale Price  Total Profit (GMROI)
# count         3000.000000  3000.000000           3000.000000
# mean           751.140000   901.574667            150.434667
# min             10.000000    11.000000              1.000000
# ...

# %%
sales_original.groupby('Product Category')['Product Category'].count()
# Out:
# Product Category
# Books                405
# Clothing             456
# Electronics          474
# Home & Kitchen       420
# Personal Care        450
# Pets                 405
# Sports & Outdoors    390
# Name: Product Category, dtype: int64

# %%
sales_original.groupby('Order Status')['Order Status'].count()
# Out:
# Order Status
# Cancelled      309
# Delivered     1205
# In Transit     323
# Shipped       1163
# Name: Order Status, dtype: int64

# %%
sales_original.groupby('State')['State'].count()
# Out:
# State
# AL    534
# FL    480
# GA    468
# LA    537
# NC    486
# SC    495
# Name: State, dtype: int64

# %%
sales_original.groupby('Sales Agent')['Sales Agent'].count()
# Out:
# Sales Agent
# Brian        571
# Daniel       572
# Kelly        644
# Priscilla    659
# Terrence     554
# Name: Sales Agent, dtype: int64

# %%
sales_original.groupby('Return Reason')['Return Reason'].count()
# Out:
# Return Reason
# Defective              59
# Late Delivery          67
# Quality Issue          44
# Received Wrong Item    73
# Unsatisfied            66
# Name: Return Reason, dtype: int64

# %% [markdown]
# Cross-field validation

# %%
sales_original[sales_original['Order Status'] == 'Cancelled'].value_counts('Return Reason', dropna = False)
# Out:
# Return Reason
# Received Wrong Item    73
# Late Delivery          67
# Unsatisfied            66
# Defective              59
# Quality Issue          44
# Name: count, dtype: int64

# %%
sales_original[~(sales_original['Return Reason'].isnull())].value_counts('Order Status', dropna = False)
# Out:
# Order Status
# Cancelled    309
# Name: count, dtype: int64

# %%
profit_check = sales_original['Total Profit (GMROI)'] - sales_original['Sale Price'] + sales_original['Manufacturer Price']
profit_check.sum()
# Out:
# 0

# %%
sales_subset = sales_original.drop_duplicates(subset = 'Customer ID', keep = 'first')
sales_subset.shape
# Out:
# (998, 14)

# %%
sales_original.groupby('Customer ID').count().sort_values(by = 'Customer Last Name', ascending = False).head(10)
# Out:
#              Order ID  Customer Last Name  Customer First Name  \
# Customer ID
# 1588                6                   6                    6
# 1373                6                   6                    6
# 1234                3                   3                    3
# 1903                3                   3                    3
# 1891                3                   3                    3
# 1892                3                   3                    3
# 1893                3                   3                    3
# 1894                3                   3                    3
# 1895                3                   3                    3
# 1896                3                   3                    3
#
#              Product Category  Order Date  Quantity Ordered  Order Status  \
# Customer ID
# 1588                        6           6                 6             6
# 1373                        6           6                 6             6
# ...

# %%
pd.merge(sales_original, df_original, on = ['Customer ID', 'Order Date'])[['Customer ID', 'Order Date', 'State_x', 'State_y', 'Product Category_x', 'Product Category_y',
                                                                           'Quantity Ordered_x', 'Quantity Ordered_y',
                                                                           'Sale Price_x', 'Sale Price_y']].head()
# Out:
#    Customer ID Order Date State_x State_y Product Category_x  \
# 0         1236 2022-12-01      GA      GA      Personal Care
# 1         1399 2022-12-01      NC      NC           Clothing
# 2         1664 2022-12-01      FL      FL      Personal Care
# 3         1881 2022-12-01      FL      FL  Sports & Outdoors
# 4         1947 2022-12-01      LA      LA     Home & Kitchen
#
#   Product Category_y  Quantity Ordered_x  Quantity Ordered_y  Sale Price_x  \
# 0      Personal Care                   7                   7          1829
# 1           Clothing                   5                   5           492
# 2      Personal Care                  13                  13          1425
# 3  Sports & Outdoors                  20                  20           689
# 4     Home & Kitchen                   3                   3          1311
#
#    Sale Price_y
# 0          1829
# 1           492
# 2          1425
# 3           689
# 4          1311

# %%
pd.merge(sales_original, df_original, on = ['Customer ID', 'Order Date'])[['Customer ID', 'Order Date', 'State_x', 'State_y', 'Product Category_x', 'Product Category_y',
                                                                           'Quantity Ordered_x', 'Quantity Ordered_y',
                                                                           'Sale Price_x', 'Sale Price_y']].shape
# Out:
# (1000, 10)
